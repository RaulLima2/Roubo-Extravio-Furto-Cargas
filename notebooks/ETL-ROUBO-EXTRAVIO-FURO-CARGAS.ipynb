# %% [markdown]
# # Carregamento dos dados

# %%
# %pip install pandas
# %pip

# %%
lista_colunas:int = []
for _ in range(len(x)):
    lista_colunas.append(len(lista_dataframes[_].columns))

plt.hist(lista_colunas, bins=10)
plt.show()

# %% [markdown]
# Nesta lista, existem datasets com número de colunas diferentes sendo o maio 12 e meno 7, o númeor padão de coluna é 9

# %%
lista_names_colunas:int = []
for _ in range(len(x)):
    lista_names_colunas =  lista_names_colunas + lista_dataframes[_].columns.tolist()

plt.figure(figsize=(20, 20))
plt.hist(lista_names_colunas, orientation='horizontal',bins=7)
plt.show()

# %% [markdown]
# - Conforme mostra nos dois graficos de histograma , a variação de quantidade de colunas e de padronização de seus nomes, tendo colunas do mesmo tipo, com nomes diferentes.
# - Também foi encontrado colunas com nome compostos, sendo um erro de transcrição de dados.
# - Foi encontrando também um número de 9 colunas que aparecem em torno de 20 vezes cada, como nome não identifica.
# - Foi encontrado também 7 colunas que mais se repetem, nas colunas do dataframe.

# %%
lista_nomes_colunas_unicos:list[str] = pd.unique(lista_names_colunas).tolist()
matrix_nomes_colunas_unicos:list[list] = [[]]

k:int = 0
n:int = len(lista_nomes_colunas_unicos) / 2

for c in range(int(n/2)):
    for k in range(int(c)):
        matrix_nomes_colunas_unicos str.
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Quantidade Roubada/ Furtada/',
#  'Unnamed: 5',
#  'Data do roubo ou',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Ordem',
#  'Produto*',
#  'Empresa*',
#  'No Lote*',
#  'Quantidade Roubada/Furtada/\rExtraviada*',
#  'No Nota Fiscal*',
#  'No Boletim de Ocorrência*',
#  'Data do roubo ou\rextravio*',
#  'Cidade*',
#  'UF*',
#  'No de Série/ Lote*',
#  'Quantidade Roubada/ Furtada/\rExtraviada*',
#  'Data do roubo ou extravio*',
#  'Cidade',
#  'UF',
#  'Quantidade Roubada/\rFurtada/ Extraviada*',
#  'Local do roubo ou extravio*',
#  'Quantidade\rRoubada/\rFurtada/\rExtraviada*',
#  'No Nota\rFiscal*',
#  'Data do roubo\rou extravio*',
#  'Local do roubo ou\rextravio*',
#  'Quantidade\rRoubada/Furtada/\rExtraviada*',
#  'Data do\rroubo ou\rextravio*',
#  'Local do roubo\rou extravio*',
#  'No Boletim de\rOcorrência*',
#  '*Quantidade\rRoubada/\rFurtada/\rExtraviada',
#  '*No Nota Fiscal*',
# ...

# %%
for _ in range(len(x)):
    print(lista_dataframes[_].columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Quantidade Roubada/ Furtada/', 'Unnamed: 5', 'Data do roubo ou',
#        'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')
# Index(['Ordem', 'Produto*', 'Empresa*', 'No Lote*',
#        'Quantidade Roubada/Furtada/\rExtraviada*', 'No Nota Fiscal*',
#        'No Boletim de Ocorrência*', 'Data do roubo ou\rextravio*', 'Cidade*',
#        'UF*'],
#       dtype='object')
# Index(['Ordem', 'Produto*', 'Empresa*', 'No de Série/ Lote*',
#        'Quantidade Roubada/ Furtada/\rExtraviada*', 'No Nota Fiscal*',
#        'No Boletim de Ocorrência*', 'Data do roubo ou extravio*', 'Cidade*',
#        'UF*'],
#       dtype='object')
# Index(['Ordem', 'Produto*', 'Empresa*', 'No Lote*',
#        'Quantidade Roubada/ Furtada/\rExtraviada*', 'No Nota Fiscal*',
#        'No Boletim de Ocorrência*', 'Data do roubo ou\rextravio*', 'Cidade',
#        'UF'],
#       dtype='object')
# ...

# %%
for _ in range(len(x)):
    print(lista_dataframes[_].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    52 non-null     object
#  1   Unnamed: 1                    55 non-null     object
#  2   Unnamed: 2                    86 non-null     object
#  3   Unnamed: 3                    53 non-null     object
#  4   Quantidade Roubada/ Furtada/  55 non-null     object
#  5   Unnamed: 5                    53 non-null     object
#  6   Data do roubo ou              53 non-null     object
#  7   Unnamed: 7                    118 non-null    object
#  8   Unnamed: 8                    47 non-null     object
# dtypes: object(9)
# memory usage: 13.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
# ...

# %%
for _ in range(len(x)):
    print(lista_dataframes[_].isna().sum())
# Out:
# Unnamed: 0                      136
# Unnamed: 1                      133
# Unnamed: 2                      102
# Unnamed: 3                      135
# Quantidade Roubada/ Furtada/    133
# Unnamed: 5                      135
# Data do roubo ou                135
# Unnamed: 7                       70
# Unnamed: 8                      141
# dtype: int64
# Ordem                                       0
# Produto*                                    0
# Empresa*                                    0
# No Lote*                                    0
# Quantidade Roubada/Furtada/\rExtraviada*    0
# No Nota Fiscal*                             0
# No Boletim de Ocorrência*                   3
# Data do roubo ou\rextravio*                 3
# Cidade*                                     0
# UF*                                         7
# dtype: int64
# Ordem                                           0
# Produto*                                        0
# ...

# %%
for _ in range(len(x)):
    print(lista_dataframes[_].isnull().sum())
# Out:
# Unnamed: 0                      136
# Unnamed: 1                      133
# Unnamed: 2                      102
# Unnamed: 3                      135
# Quantidade Roubada/ Furtada/    133
# Unnamed: 5                      135
# Data do roubo ou                135
# Unnamed: 7                       70
# Unnamed: 8                      141
# dtype: int64
# Ordem                                       0
# Produto*                                    0
# Empresa*                                    0
# No Lote*                                    0
# Quantidade Roubada/Furtada/\rExtraviada*    0
# No Nota Fiscal*                             0
# No Boletim de Ocorrência*                   3
# Data do roubo ou\rextravio*                 3
# Cidade*                                     0
# UF*                                         7
# dtype: int64
# Ordem                                           0
# Produto*                                        0
# ...

# %%
for _ in range(len(x)):
    print(lista_dataframes[_].describe())
# Out:
#        Unnamed: 0                 Unnamed: 1               Unnamed: 2  \
# count          52                         55                       86
# unique         51                         26                       18
# top         Ordem  COLFLEX COMPLET FR 60 CPR  COSMED IND COSM MED S/A
# freq            2                          6                       13
#
#        Unnamed: 3 Quantidade Roubada/ Furtada/  Unnamed: 5 Data do roubo ou  \
# count          53                           55          53               53
# unique         36                           45          17               17
# top      007C0720                     3 660952  17.565.444       18/12/2020
# freq            6                            3          22               22
#
#                          Unnamed: 7 Unnamed: 8
# count                           118         47
# unique                           18          7
# top     TRANSPORTE E LOGISTICA, VIA         GO
# ...

# %% [markdown]
# #### Conclusão da Analise Previa dos Dados
# - Existêm dataset com 9, 10 e 12 colunas
# - Existem colunas com nomes diferentes
# - Existem colunas com dados vazios
# - Têm dataset com o cabeçalho na primeira linha e outros não
